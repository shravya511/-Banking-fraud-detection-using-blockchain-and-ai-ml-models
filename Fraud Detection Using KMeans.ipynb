# %% [markdown]
# # Banking Fraud Detection using Blockchain and AIML Models

# %% [markdown]
# ## Fraud Detection Using KMeans

# %% [markdown]
# #### Import Libraries

# %%
import numpy as np
import scipy
import pandas as pd
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_moons
from sklearn.cluster import SpectralClustering

# %% [markdown]
# #### Import Data

# %%
client= pd.read_csv("datasets/client.csv",sep=';')
card= pd.read_csv("datasets/card.csv",sep=';')#client,card,disp
disp= pd.read_csv("datasets/disp.csv",sep=';')

# %% [markdown]
# ## Process Demo
#
# Demonstration of the working of KMeans clustering with visualization of the output.

# %% [markdown]
# ### Order & Account Dataframes

# %%
#working with 'order' dataframe and 'account' dataframe
x = (client['client_id'],client['birth_number'],client['district_id'])
y = (card['card_id'],card['disp_id'],card['type'])

# %%
# Splitting the dataset into the Training set and Test set
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)
sc_y = StandardScaler()
y_train = sc_y.fit_transform(y_train)

# %% [markdown]
# #### Applying KMeans

# %%
kmeans = KMeans(n_clusters = 3, init = 'k-means++', random_state = 42)
y_kmeans = kmeans.fit_predict(x)

# %% [markdown]
# #### Visualize the Clusters

# %%
x, y = make_moons(200, noise=.05, random_state=0)
labels = KMeans(2, random_state=0).fit_predict(x)
plt.scatter(x[:, 0], x[:, 1], c=labels,
            s=50, cmap='viridis');

# %% [markdown]
# ###  <center> -------------------- End of Demo --------------------

# %% [markdown]
# ###### I skipped the visualizations for the rest of the analysis procedure as it is not needed for the main program.

# %% [markdown]
# ### Order & Transaction Dataframes

# %%
# working with 'order' dataframe and 'transaction' dataframe
a = (client['client_id'],client['birth_number'],client['district_id'])
b = (disp['disp_id'],disp['client_id'],disp['type'])

# %%
# Splitting the dataset into the Training set and Test set
X_train, X_test, y_train, y_test = train_test_split(a, b, test_size = 0.2, random_state = 0)

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)
sc_y = StandardScaler()
y_train = sc_y.fit_transform(y_train)

# %%
kmeans = KMeans(n_clusters = 3, init = 'k-means++', random_state = 42)
y_kmeans = kmeans.fit_predict(a)

# %% [markdown]
# ### Account & Transaction Dataframes

# %%
# working with 'account' dataframe and 'transaction' dataframe
e = (card['card_id'],card['disp_id'])
f = (disp['disp_id'],disp['client_id'])

# %%
# Splitting the dataset into the Training set and Test set
X_train, X_test, y_train, y_test = train_test_split(e,f, test_size = 0.2, random_state = 0)

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)
sc_y = StandardScaler()
y_train = sc_y.fit_transform(y_train)

# %%
kmeans = KMeans(n_clusters = 2, init = 'k-means++', random_state = 42)
y_kmeans = kmeans.fit_predict(e)

# %% [markdown]
# ##### Note:
# The dataset consisists of several csv files, but I have used only three of the files they serve the pupose of my research. the files I used are:
#
# 1) order.csv
#
# 2) account.csv
#
# 3) transaction.csv
